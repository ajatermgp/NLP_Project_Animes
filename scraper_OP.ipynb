# %%
import fandom
import io

fandom.set_wiki("OnePiece")

# %% [markdown]
# Im folgenden sind einige Versuche zu sehen, die genaue Anzahl an vorhandenen Seiten im Wiki zu ermitteln, da die Angabe auf der Statistik-Seite leider falsch war und weniger Seiten tatsächlich vorhanden waren.

# %%
test = fandom.page("Ruffy")
test.plain_text
# Out:
# 'Monkey D. Luffy\nFor other uses, see Straw Hat Luffy (Disambiguation).\nFor the chapters of the same name, see Chapter 2 and Chapter 1000.\nMonkey D. Luffy, commonly known as "Straw Hat Luffy" or simply "Straw Hat", is the founder, captain, and strongest combatant of the increasingly infamous and powerful Straw Hat Pirates. He fearlessly pursues the legendary treasure of the late Gol D. Roger in order to become the new Pirate King and reach a further, untold dream (currently known to only his crew and closest friends). He believes that being the Pirate King means having the most freedom in the world.\nBorn on Dawn Island, Luffy is the son of Revolutionary leader Monkey D. Dragon and grandson of the Marine hero Monkey D. Garp and as such is a member of the Clan of D. Most of his childhood was shaped by Garp and Curly Dadan, under whose care he befriended and swore brotherhood to the late Portgas D. "Fire Fist" Ace and Sabo. However, he draws his greatest inspiration from the pirate "
# ...

# %%
test = fandom.page("Pudding")
test.plain_text
# Out:
# 'Charlotte Pudding\nFor the Marine commodore of the 77th Branch, see Pudding Pudding.\nCharlotte Pudding is the 35th daughter and the 76th child of the Charlotte Family, an officer of the Big Mom Pirates, and a hybrid between a human and a member of the Three-Eye Tribe. She also works as a chocolatier and the owner of cafe "Caramel" on Cacao Island, as the candidate for the vacant position of Minister of Chocolate (チョコレート大臣, Chokorēto Daijin?). She was once Sanji\'s arranged fiancée, per the political agreement between their families. She is currently held captive by the Blackbeard Pirates.\nDue to her actions and role, she was initially a major antagonist in the Whole Cake Island Arc, but after genuinely falling in love with Sanji, this changed as she tried to help the Straw Hat Pirates escape from her mother, Charlotte Linlin. She is also a supporting character in the Germa 66\'s Ahh... An Emotionless Excursion cover page serial.\nAppearance\nPudding is a teenage girl with round, r
# ...

# %%
ges_op = {}

7365
while len(ges_op) < 7360:
    try:
        ra_op = fandom.random(500)
        ges_op.update(ra_op)
    except:
        print("something wrong")
        break

# %%
ges_op2 = {}


while len(ges_op2) < 7362:
    try:
        ra_op2 = fandom.random(100)
        ges_op2.update(ra_op2)
    except:
        print("something wrong")
        break

# %%
ges_op4 = {}


while len(ges_op4) < 7363:
    try:
        ra_op4 = fandom.random(100)
        ges_op4.update(ra_op4)
    except:
        print("something wrong")
        break

# %%
ges_op
# Out:
# {'Yakigashi Island': 303513,
#  'Rainbow Island': 346674,
#  'Pero Pero no Mi': 288429,
#  'Utae! Jingle Bell': 7556,
#  'Hannari Fall in Love': 328526,
#  'Impel Down': 2654,
#  'Ramba': 46160,
#  'Chapter 1015': 329125,
#  'Chapter 305': 5884,
#  'Episode 1062': 341091,
#  'Chapter 365': 5807,
#  'Goldfish Empire': 46267,
#  'Dial Boat': 53911,
#  'Dock Island': 183064,
#  'Honnete': 341820,
#  'Aladine': 75437,
#  'Episode 1033': 336567,
#  'Miss Goldenweek\'s "Operation: Meet Baroque Works"': 7695,
#  'Ahiru': 316446,
#  'Dorry': 2090,
#  'Glove': 39533,
#  'Bilić': 179864,
#  'Kitton': 23173,
#  'Chapter 334': 5913,
#  'Prince Grus': 336983,
#  'From the Decks of the World': 62670,
#  'Tokyo One Piece Tower': 297159,
#  'Chapter 524': 10863,
#  'Birthday Products': 338299,
#  'Nine Red Scabbards': 313649,
#  'Episode Special 4': 1572,
#  'Rasa': 8270,
#  'Kyuka Island': 8340,
#  'Chapter 896': 305661,
#  'Episode 749': 287364,
#  'Buster Call': 2651,
#  'SBS Volume 31': 26299,
# ...

# %%
f_op = io.open("dictionary_op.txt", "a", encoding  ="utf-8")
for key in ges_op4:
    f_op.write(key + "\n")
f_op.close()


w_pointer_op = io.open("dump_op.txt", "a", encoding='utf-8')
file_op = open("dictionary_op.txt", encoding="utf-8")
for line in file_op:
    if line != "":
        try:
            print(line)
            element_op = fandom.page(line.rstrip("\n"))
            element_op = element_op.plain_text

            #print(element_op)
            w_pointer_op.write(element_op + "\n\n")
        except:
            continue

w_pointer_op.close()
# Out:
# Eric
#
# Tsui Village
#
# Jessica
#
# Saki (Non-Canon)
#
# SBS Volume 15
#
# Episode 945
#
# Lu Feld
#
# Episode 8
#
# Corrida Colosseum
#
# Monet
#
# Vivre Card - One Piece Visual Dictionary
#
# Cloud Drifting
#
# Episode 702
#
# Soran
#
# Chapter 1061
#
# Creese
#
# Cands
#
# Shiki
#
# King (Giant Squid)
#
# Royal Sun Island
#
# Davy Back Fight
#
# Episode 514
#
# Tam
#
# Chapter 970
#
# Chapter 797
#
# Episode 506
#
# Episode 672
#
# Chapter 957
#
# Nodoi Wakan
#
# Gérard
#
# Pekoms
#
# My Plans Never Fail!!
#
# Eikon
#
# Lulusia Kingdom
#
# Chapter 550
#
# Rope Action
#
# Chapter 644
#
# Chapter 136
#
# Flower Capital
#
# Chapter 1072
#
# Demon of Doom
#
# Arlong Park
#
# Kerojii
#
# Great Fierce Battle Special! Alliance Counterattack vs. Big Mom
#
# Ko
#
# Episode 509
#
# Meryl
#
# Episode 219
#
# Mitt
#
# Ratchet
#
# Pepe Kingdom
#
# Chapter 248
#
# Daimyo
#
# Chapter 586
#
# Episode 759
#
# Gomorrah
#
# Episode 391
#
# Trafalgar D. Water Law/History
#
# MADS
#
# FAITH
#
# ...
